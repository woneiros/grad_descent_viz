# %% [markdown]
# ## Gradient Descent Visualization
#
# **Visualizing Stochastic Gradient Descent on the run**
#
# The following dashboard is built to help explore and develop intuitive understanding of how stochastic gradient descent iteratively updates the classification boundary (hyperplane).

# %%
# %matplotlib inline
from grad_desc_gui import dashboard

# %%
dashboard
# Out:
# INITIAL WEIGHTS - slope: 2.00   offset: 0.50
#  -> Using datapoint (-2,3) :
# STEP #1 WEIGHTS - slope: -1.00   offset: 2.00
#  -> Using datapoint (-1,-1) :
# STEP #2 WEIGHTS - slope: -0.50   offset: 1.50
#  -> Using datapoint (2,-3) :
# STEP #3 WEIGHTS - slope: -3.50   offset: 0.00

# %% [markdown]
# Developed by [Ankit Tharwani](https://github.com/ankittharwani) and [Guillermo (Will) Monge](https://github.com/WillahScott).
#
# *View the source code [here](https://github.com/WillahScott/grad_descent_viz)*
